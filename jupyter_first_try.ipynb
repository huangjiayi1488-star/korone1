# %%
# 这是我的第一个 Python 代码示例
print("Hello, Jupyter!")

# 矩阵运算示例
import numpy as np
a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6], [7, 8]])
print("矩阵相加结果: ")
print(a + b)
print("矩阵相乘结果: ")
print(a @ b)
# Out:
# Hello, Jupyter!
# 矩阵相加结果:
# [[ 6  8]
#  [10 12]]
# 矩阵相乘结果:
# [[19 22]
#  [43 50]]
